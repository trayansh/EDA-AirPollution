# %%
l = [1,2,3,4,2,2,'ok','ook','4']

# %%
temp = dict()
for x in l:
    if(x not in temp.keys()):
        temp[x] = 1
    else:
        temp[x] += 1

# %%
print(temp)
# Out:
# {1: 1, 3: 2, 6: 1, 2: 2, 'ok': 1, 'ook': 1, '4': 1}
